# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepFluxion/2026_2_IBMEC_PROG_ANALISE_DADOS/blob/main/notebooks/Liista_Exercicios_1/LE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Lista de Exercícios — Programação para Análise de Dados
#
# **Disciplina:** Programação para Análise de Dados
# **Professor:** Carlos E. Leal de Castro
# **Pontuação total:** 10,0 pontos
#
# ---
#
# ## Instruções
#
# - Todas as questões operam sobre o DataFrame `df` criado na **Célula de Setup** abaixo.
# - Execute a célula de setup **antes** de qualquer outra célula.
# - Nas questões com `____________`, substitua pelo código correto.
# - Nas questões abertas, escreva o comando na célula indicada com `# TODO`.
# - As respostas devem ser concisas — uma linha ou poucos termos por espaço.
#
# | Dificuldade | Questões | Pts/Questão | Total |
# |---|---|---|---|
# | 🟢 Fácil | Q1 – Q10 | 0,3 | 3,0 pts |
# | 🟡 Médio | Q11 – Q15 | 0,6 | 3,0 pts |
# | 🔴 Difícil | Q16 – Q20 | 0,8 | 4,0 pts |
# | **Total** | **20** | — | **10,0 pts** |

# %% [markdown]
# ## ⚙️ Célula de Setup — Execute primeiro!

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'id_pedido':        [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010,
                         1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020],
    'data_pedido':      ['15/01/2024', '23/01/2024', '02/02/2024', '14/02/2024', '28/02/2024',
                         '05/03/2024', '19/03/2024', '01/04/2024', '12/04/2024', '25/04/2024',
                         '03/05/2024', '17/05/2024', '29/05/2024', '07/06/2024', '20/06/2024',
                         '04/07/2024', '18/07/2024', '02/08/2024', '16/08/2024', '30/08/2024'],
    'vendedor':         ['Alice', 'Bruno', 'Alice', np.nan, 'Carlos',
                         'Bruno', 'Alice', 'Carlos', np.nan, 'Bruno',
                         'Alice', 'Carlos', 'Bruno', 'Alice', np.nan,
                         'Carlos', 'Bruno', 'Alice', 'Carlos', 'Bruno'],
    'regiao':           ['Sudeste', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste',
                         'Sudeste', 'Norte', 'Nordeste', 'Sul', 'Sudeste',
                         'Centro-Oeste', 'Norte', 'Nordeste', 'Sudeste', 'Sul',
                         'Sudeste', 'Nordeste', 'Norte', 'Sul', 'Centro-Oeste'],
    'produto':          ['Notebook', 'Geladeira', 'Smartphone', 'TV 55"', 'Cadeira Gamer',
                         'Notebook', 'Tablet', 'Geladeira', 'Smartphone', 'TV 55"',
                         'Notebook', 'Cadeira Gamer', 'Tablet', 'Geladeira', 'Notebook',
                         'Smartphone', 'TV 55"', 'Tablet', 'Cadeira Gamer', 'Geladeira'],
    'categoria':        ['Eletrônico', 'Eletrodoméstico', 'Eletrônico', 'Eletrônico', 'Móvel',
                         'Eletrônico', 'Eletrônico', 'Eletrodoméstico', 'Eletrônico', 'Eletrônico',
                         'Eletrônico', 'Móvel', 'Eletrônico', 'Eletrodoméstico', 'Eletrônico',
                         'Eletrônico', 'Eletrônico', 'Eletrônico', 'Móvel', 'Eletrodoméstico'],
    'quantidade':       [2, 1, 3, 1, 4, 2, 5, np.nan, 2, 1,
                         3, 2, 1, np.nan, 2, 4, 1, 3, 2, 1],
    'preco_unitario':   [3500.0, 2800.0, 1200.0, 4500.0,  750.0,
                         3600.0,  900.0, 2750.0, 1150.0, 4200.0,
                         3400.0,  800.0,  950.0, 2900.0, 3700.0,
                         1100.0, 4300.0,  880.0,  720.0, 2650.0],
    'desconto_pct':     [0.05, np.nan, 0.10, 0.00, 0.15,
                         0.05, np.nan, 0.00, 0.10, 0.05,
                         np.nan, 0.15, 0.00, 0.05, 0.10,
                         np.nan, 0.00, 0.05, 0.15, 0.10],
    'nivel_satisfacao': ['Bom', 'Excelente', 'Regular', 'Bom', np.nan,
                         'Excelente', 'Bom', 'Regular', 'Bom', 'Excelente',
                         np.nan, 'Regular', 'Bom', 'Excelente', 'Bom',
                         'Regular', np.nan, 'Bom', 'Excelente', 'Regular']
})

print("DataFrame criado com sucesso!")
print(f"Shape: {df.shape}")
df.head()

# %% [markdown]
# ---
# ## 🟢 Questões Fáceis — 0,3 ponto cada

# %% [markdown]
# ### Questão 1 🟢 FÁCIL — 0.3 pt
#
# **Dimensões do DataFrame**
#
# Qual é o número de linhas e colunas do DataFrame `df`? Escreva o comando que retorna uma tupla `(linhas, colunas)`.

# %%
# TODO: escreva o comando que retorna (linhas, colunas)

# %% [markdown]
# ### Questão 2 🟢 FÁCIL — 0.3 pt
#
# **Tipos de Dados**
#
# Exiba o tipo de dado (dtype) de cada coluna do DataFrame.

# %%
# TODO

# %% [markdown]
# ### Questão 3 🟢 FÁCIL — 0.3 pt
#
# **Estatísticas Descritivas**
#
# Gere as estatísticas descritivas das colunas numéricas do DataFrame (contagem, média, desvio padrão, mínimo, quartis e máximo).

# %%
# TODO

# %% [markdown]
# ### Questão 4 🟢 FÁCIL — 0.3 pt
#
# **Contagem de Valores Ausentes**
#
# Conte quantos valores ausentes (NaN) existem em cada coluna do DataFrame.

# %%
# TODO

# %% [markdown]
# ### Questão 5 🟢 FÁCIL — 0.3 pt
#
# **Seleção de Colunas**
#
# Selecione apenas as colunas `produto` e `preco_unitario` do DataFrame.

# %%
# TODO

# %% [markdown]
# ### Questão 6 🟢 FÁCIL — 0.3 pt
#
# **Primeiras Linhas**
#
# Exiba as **3 primeiras** linhas do DataFrame.

# %%
# TODO

# %% [markdown]
# ### Questão 7 🟢 FÁCIL — 0.3 pt
#
# **Filtro por Igualdade**
#
# Filtre e exiba apenas os pedidos da região `'Sudeste'`.

# %%
# TODO

# %% [markdown]
# ### Questão 8 🟢 FÁCIL — 0.3 pt
#
# **Seleção por Posição — `.iloc`**
#
# Use `.iloc` para selecionar as linhas de **posição 2 a 4** (inclusive, ou seja, índices 2, 3 e 4).

# %%
# TODO

# %% [markdown]
# ### Questão 9 🟢 FÁCIL — 0.3 pt
#
# **Criação de Nova Coluna**
#
# Crie a coluna `valor_total` como o produto de `quantidade` × `preco_unitario`.
#
# > ⚠️ **Atenção:** esta coluna será usada nas questões seguintes — execute esta célula antes de continuar.

# %%
# TODO: crie a coluna valor_total

df.head()

# %% [markdown]
# ### Questão 10 🟢 FÁCIL — 0.3 pt
#
# **Resumo Geral do DataFrame**
#
# Exiba um resumo geral do DataFrame mostrando os tipos de dados, a contagem de valores não-nulos e o uso de memória.

# %%
# TODO

# %% [markdown]
# ---
# ## 🟡 Questões Médias — 0,6 ponto cada

# %% [markdown]
# ### Questão 11 🟡 MÉDIO — 0.6 pt
#
# **Máscara Booleana Composta**
#
# Complete o código para filtrar pedidos onde **`preco_unitario > 2000`** E **`categoria == 'Eletrônico'`** usando uma máscara booleana.

# %%
mascara = (____________) & (____________)
resultado = df[mascara]
print(f"Pedidos encontrados: {len(resultado)}")
resultado

# %% [markdown]
# ### Questão 12 🟡 MÉDIO — 0.6 pt
#
# **Tratamento de Valores Ausentes — fillna + média**
#
# Complete o código para tratar os valores ausentes: preencha `desconto_pct` com `0.0` e `quantidade` com a **média** da coluna.

# %%
df_trat = df.copy()

# Preencha desconto_pct com 0.0
df_trat['desconto_pct'] = ____________

# Preencha quantidade com a média da coluna
df_trat['quantidade'] = ____________

print(df_trat.isnull().sum())

# %% [markdown]
# ### Questão 13 🟡 MÉDIO — 0.6 pt
#
# **Conversão de Datas e Extração de Componentes**
#
# Complete o código para converter a coluna `data_pedido` (string no formato `'dd/mm/yyyy'`) para o tipo `datetime` e criar a coluna `mes_pedido` com o número do mês.

# %%
df['data_pedido'] = pd.to_datetime(____________, format=____________)
df['mes_pedido']   = ____________
df[['data_pedido', 'mes_pedido']].head()

# %% [markdown]
# ### Questão 14 🟡 MÉDIO — 0.6 pt
#
# **Agrupamento e Ordenação — groupby + sort_values**
#
# Use `groupby` para calcular a **soma** de `valor_total` por `regiao` e ordene o resultado do **maior para o menor**.

# %%
resultado = df.groupby(____________)[____________].____________().____________(ascending=False)
resultado

# %% [markdown]
# ### Questão 15 🟡 MÉDIO — 0.6 pt
#
# **Seleção com `.loc` — máscara + colunas**
#
# Use `.loc` para selecionar as colunas `vendedor`, `produto` e `valor_total` somente das linhas onde `nivel_satisfacao == 'Excelente'`.

# %%
resultado = df.loc[____________, ____________]
resultado

# %% [markdown]
# ---
# ## 🔴 Questões Difíceis — 0,8 ponto cada

# %% [markdown]
# ### Questão 16 🔴 DIFÍCIL — 0.8 pt
#
# **Pivot Table**
#
# Complete o código para criar uma pivot table com a **média** de `valor_total` por `regiao` (linhas) e `categoria` (colunas).

# %%
pivot = pd.pivot_table(
    df,
    values=____________,
    index=____________,
    columns=____________,
    aggfunc=____________
)
pivot

# %% [markdown]
# ### Questão 17 🔴 DIFÍCIL — 0.8 pt
#
# **Agregação com .agg() e Nomes Personalizados**
#
# Complete o script usando `.agg()` para calcular, por `categoria`: a **soma** de `valor_total` (→ `total_vendas`), a **média** de `preco_unitario` (→ `preco_medio`) e a **contagem** de pedidos (→ `num_pedidos`).

# %%
resumo = df.groupby('categoria').agg(
    total_vendas = (____________, ____________),
    preco_medio  = (____________, ____________),
    num_pedidos  = (____________, ____________)
)
resumo

# %% [markdown]
# ### Questão 18 🔴 DIFÍCIL — 0.8 pt
#
# **Variável Categórica Ordinal e Filtro Comparativo**
#
# Complete o código para: (a) converter `nivel_satisfacao` em variável categórica **ordinal** com a ordem `Ruim < Regular < Bom < Excelente`; (b) filtrar apenas pedidos com satisfação **maior que** `'Regular'`.

# %%
ordem = ____________

df['nivel_satisfacao'] = pd.Categorical(
    df['nivel_satisfacao'],
    categories=____________,
    ordered=____________
)

# Filtrar apenas satisfação > 'Regular'
df_filtrado = df[____________]
df_filtrado[['produto', 'nivel_satisfacao']]

# %% [markdown]
# ### Questão 19 🔴 DIFÍCIL — 0.8 pt
#
# **Discretização por Frequência — pd.qcut()**
#
# Complete o código para discretizar `preco_unitario` em **4 faixas de igual frequência** usando `pd.qcut()`, com labels `['Econômico', 'Padrão', 'Premium', 'VIP']`. Em seguida, exiba a contagem de pedidos em cada faixa.

# %%
df['faixa_preco'] = pd.qcut(
    df[____________],
    q=____________,
    labels=____________,
    duplicates='drop'
)
print(df['faixa_preco'].____________())

# %% [markdown]
# ### Questão 20 🔴 DIFÍCIL — 0.8 pt
#
# **Percentual de Ausentes + Discretização Manual — pd.cut()**
#
# Complete o script que: **(a)** calcula o percentual de ausentes por coluna; **(b)** exibe apenas colunas com ausência > 0%; **(c)** cria faixas manuais de `preco_unitario` com `pd.cut()` usando fronteiras `[0, 1000, 2000, 3000, 5000]` e labels `['Baixo', 'Médio', 'Alto', 'Premium']`.

# %%
# (a) Percentual de ausentes
pct_ausentes = (____________ / len(df) * 100).round(2)

# (b) Exibir apenas colunas com ausência > 0%
print(pct_ausentes[____________])

# (c) Discretizar preco_unitario com fronteiras manuais
df['faixa_manual'] = pd.cut(
    df['preco_unitario'],
    bins=____________,
    labels=____________,
    include_lowest=True
)
df[['preco_unitario', 'faixa_manual']].head(8)
